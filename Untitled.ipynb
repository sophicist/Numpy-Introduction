# %%
#importing the library
import numpy as np

# %% [markdown]
# # <font color="cyan">Data types</font>

# %%
a = int(1) # a = integer
b = 1.324  # b =  float
c = True   # c is boolean
d = "thende" # d is a string/ categorical ["male","female"] can also be ordinal {low,high mid}
import datetime
datetime.date.today()# date data
# geo data include logitudes and latitudes
# Out:
# datetime.date(2020, 7, 5)

# %% [markdown]
# # Random numbers  =  normal and uniform

# %%
# similar to random numbers using random library
df = np.random.randint(100,1000,(10000,4))#first two numbers (between), the other two are the shape of the data
mu, sigma = 0, 0.1
dt = np.random.normal(mu, sigma, (1000,4))
#import pandas as pd
pd.DataFrame(df,columns = ["c1","c2","c3","c4"]).plot(kind = "density",title = "Uniform distribution")
pd.DataFrame(dt,columns = ["c1","c2","c3","c4"]).plot(kind = "density",title = "Normal distribution")
#df

# %% [markdown]
# # Numpy functions

# %%
df.mean()# mean for all the columns and rows
df.mean(axis = 1)#.shape # mean rowise
df.mean(axis =0)  # mean columwise

df.max()
df.min()
df.std()
ages = [23,78,90,10]
age = np.array(ages)
age.std()
# Out:
# 34.3247359785913

# %% [markdown]
# # Numpy arrays

# %%
y = np.array([
    [23,45],
    [90,78]])
x = np.array([
    [203,450],
    [900,708]])
# Out:
# array([[203, 450],
#        [900, 708]])

# %%
y.mean(axis =0)
# Out:
# array([56.5, 61.5])

# %%
y
# Out:
# array([[23, 45],
#        [90, 78]])

# %% [markdown]
# # Numpy subsetting and slicing

# %% [markdown]
# ## Subseting

# %%
y[0,0] # array[row,column] in integer location
y[1,1]
# Out:
# 78

# %%
df[:10,:]
# Out:
# array([[346, 594, 910, 899],
#        [437, 224, 513, 541],
#        [186, 288, 620, 812],
#        [182, 228, 967, 526],
#        [724, 282, 663, 455],
#        [641, 159, 884, 975],
#        [238, 142, 127, 758],
#        [169, 104, 834, 364],
#        [838, 502, 668, 317],
#        [756, 150, 646, 793]])

# %%
df [2,1] # get an item from the array
# Out:
# 288

# %% [markdown]
# ## slicing

# %%
df[2:7,1:3]
# Out:
# array([[288, 620],
#        [228, 967],
#        [282, 663],
#        [159, 884],
#        [142, 127]])

# %% [markdown]
# # Null value

# %%
np.nan
# Out:
# nan
